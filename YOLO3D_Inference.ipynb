# %% [markdown]
# # YOLO3D Inference

# %% [markdown]
# ## Clone and Installation

# %%
# %cd /content/
# !rm -rf YOLO3D
# Out:
# /content

# %%
# %cd /content/
# !git clone https://github.com/ruhyadi/YOLO3D
# Out:
# /content
# Cloning into 'YOLO3D'...
# remote: Enumerating objects: 734, done.
# remote: Counting objects: 100% (259/259), done.
# remote: Compressing objects: 100% (203/203), done.
# remote: Total 734 (delta 72), reused 227 (delta 44), pack-reused 475
# Receiving objects: 100% (734/734), 24.87 MiB | 15.92 MiB/s, done.
# Resolving deltas: 100% (264/264), done.

# %%
# install requirements
# %cd /content/YOLO3D

# !pip install -q --upgrade --no-cache-dir gdown
# Out:
# /content/YOLO3D

# %%
# get weights
# %cd /content/YOLO3D/weights/
# !python get_weights.py --weights 'resnet18'
# Out:
# /content/YOLO3D/weights
# Downloading...
# From: https://drive.google.com/uc?id=1k_v1RrDO6da_NDhBtMZL5c0QSogCmiRn
# To: /content/YOLO3D/weights/resnet18.pkl
# 100% 298M/298M [00:01<00:00, 171MB/s]

# %% [markdown]
# ## Inference

# %%
# %cd /content/YOLO3D/
# !python inference.py \
  --weights yolov5s.pt \
  --source /content/YOLO3D/eval/image_2 \
  --reg_weights weights/resnet18.pkl \
  --model_select resnet18 \
  --output_path runs01 \
  --save_result
# Out:
# /content/YOLO3D
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# inference: weights=['yolov5s.pt'], source=/content/YOLO3D/eval/image_2, data=data/coco128.yaml, imgsz=[640, 640], device=, classes=[0, 2, 3, 5], reg_weights=weights/resnet18.pkl, model_select=resnet18, calib_file=eval/camera_cal/calib_cam_to_cam.txt, show_result=False, save_result=True, output_path=runs01
# YOLOv5 🚀 4c3027f torch 1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v6.2/yolov5s.pt to yolov5s.pt...
# 100% 14.1M/14.1M [00:00<00:00, 251MB/s]
#
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients
# Traceback (most recent call last):
#   File "inference.py", line 285, in <module>
#     main(opt)
#   File "inference.py", line 280, in main
#     output_path=opt.output_path
#   File "inference.py", line 93, in detect3d
#     classes=[0, 2, 3, 5]
#   File "/usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
#   File "inference.py", line 169, in detect2d
#     model.warmup(imgsz=(1, 3, *imgsz), half=False)  # warmup
#   File "/content/YOLO3D/models/common.py", line 460, in warmup
#     self.forward(im)  # warmup
#   File "/content/YOLO3D/models/common.py", line 397, in forward
#     y = self.model(im) if self.jit else self.model(im, augment=augment, visualize=visualize)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 1130, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/content/YOLO3D/models/yolo.py", line 126, in forward
#     return self._forward_once(x, profile, visualize)  # single-scale inference, train
#   File "/content/YOLO3D/models/yolo.py", line 149, in _forward_once
#     x = m(x)  # run
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 1130, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/upsampling.py", line 154, in forward
#     recompute_scale_factor=self.recompute_scale_factor)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 1208, in __getattr__
#     type(self).__name__, name))
# AttributeError: 'Upsample' object has no attribute 'recompute_scale_factor'

# %% [markdown]
# ## Show Result

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.cvtColor(cv2.imread('/content/YOLO3D/eval/image_2/000010.png'), cv2.COLOR_BGR2RGB)

plt.figure(figsize=(15, 8))
plt.imshow(img)
plt.axis('off')
plt.show()
