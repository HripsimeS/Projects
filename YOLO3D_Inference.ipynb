# %% [markdown]
# # YOLO3D Inference

# %%
# get weights
# %cd C:/YOLO3D/weights/
# !python get_weights.py --weights resnet18
# Out:
# C:\YOLO3D\weights
# Downloading...
# From: https://drive.google.com/uc?id=1k_v1RrDO6da_NDhBtMZL5c0QSogCmiRn
# To: C:\YOLO3D\weights\resnet18.pkl
#
#   0%|          | 0.00/298M [00:00<?, ?B/s]
#   1%|          | 2.10M/298M [00:00<00:14, 19.7MB/s]
#   2%|1         | 4.72M/298M [00:00<00:13, 21.3MB/s]
#   2%|2         | 7.34M/298M [00:00<00:12, 23.0MB/s]
#   3%|3         | 9.96M/298M [00:00<00:14, 20.1MB/s]
#   4%|4         | 12.6M/298M [00:00<00:13, 21.3MB/s]
#   5%|5         | 15.2M/298M [00:00<00:12, 22.5MB/s]
#   6%|5         | 17.8M/298M [00:00<00:11, 23.6MB/s]
#   7%|7         | 21.0M/298M [00:00<00:11, 25.0MB/s]
#   8%|7         | 23.6M/298M [00:01<00:10, 25.0MB/s]
#   9%|8         | 26.7M/298M [00:01<00:10, 25.7MB/s]
#  10%|#         | 29.9M/298M [00:01<00:10, 26.2MB/s]
#  11%|#1        | 33.0M/298M [00:01<00:10, 25.2MB/s]
#  12%|#1        | 35.7M/298M [00:01<00:10, 25.4MB/s]
#  13%|#2        | 38.3M/298M [00:01<00:10, 24.6MB/s]
#  14%|#3        | 41.4M/298M [00:01<00:10, 25.0MB/s]
#  15%|#4        | 44.0M/298M [00:01<00:10, 25.1MB/s]
#  16%|#5        | 47.2M/298M [00:01<00:10, 24.3MB/s]
#  17%|#6        | 50.3M/298M [00:02<00:09, 25.0MB/s]
#  18%|#7        | 53.5M/298M [00:02<00:09, 25.1MB/s]
#  19%|#8        | 56.1M/298M [00:02<00:09, 25.3MB/s]
#  20%|#9        | 58.7M/298M [00:02<00:09, 25.3MB/s]
#  21%|##        | 61.9M/298M [00:02<00:09, 26.1MB/s]
#  22%|##1       | 64.5M/298M [00:02<00:08, 26.1MB/s]
#  23%|##2       | 67.1M/298M [00:02<00:08, 26.1MB/s]
#  23%|##3       | 69.7M/298M [00:02<00:09, 25.0MB/s]
#  24%|##4       | 72.4M/298M [00:02<00:09, 24.5MB/s]
#  25%|##5       | 75.5M/298M [00:03<00:08, 25.9MB/s]
#  26%|##6       | 78.1M/298M [00:03<00:08, 25.1MB/s]
#  27%|##7       | 80.7M/298M [00:03<00:08, 25.4MB/s]
#  28%|##8       | 83.4M/298M [00:03<00:08, 25.2MB/s]
#  29%|##9       | 86.5M/298M [00:03<00:08, 26.1MB/s]
#  30%|##9       | 89.1M/298M [00:03<00:08, 26.0MB/s]
#  31%|###       | 91.8M/298M [00:03<00:08, 25.4MB/s]
#  32%|###1      | 94.9M/298M [00:03<00:07, 26.8MB/s]
#  33%|###2      | 98.0M/298M [00:03<00:07, 26.7MB/s]
#  34%|###3      | 101M/298M [00:04<00:07, 25.3MB/s]
#  35%|###5      | 104M/298M [00:04<00:07, 25.7MB/s]
#  36%|###5      | 107M/298M [00:04<00:07, 25.6MB/s]
#  37%|###6      | 110M/298M [00:04<00:07, 26.4MB/s]
#  38%|###8      | 113M/298M [00:04<00:07, 25.6MB/s]
#  39%|###9      | 116M/298M [00:04<00:07, 24.7MB/s]
#  85%|########4 | 252M/298M [00:10<00:01, 25.1MB/s]
#  86%|########5 | 255M/298M [00:10<00:01, 25.4MB/s]
#  86%|########6 | 257M/298M [00:10<00:01, 20.3MB/s]
#  87%|########7 | 260M/298M [00:10<00:01, 20.6MB/s]
#  88%|########8 | 263M/298M [00:10<00:01, 22.0MB/s]
#  89%|########9 | 265M/298M [00:10<00:01, 22.7MB/s]
#  90%|########9 | 268M/298M [00:10<00:01, 23.0MB/s]
#  91%|#########1| 271M/298M [00:11<00:01, 23.4MB/s]
#  92%|#########2| 274M/298M [00:11<00:00, 23.6MB/s]
#  93%|#########2| 277M/298M [00:11<00:00, 23.8MB/s]
#  94%|#########4| 280M/298M [00:11<00:00, 24.8MB/s]
#  95%|#########4| 283M/298M [00:11<00:00, 25.1MB/s]
#  96%|#########5| 285M/298M [00:11<00:00, 25.4MB/s]
#  97%|#########6| 288M/298M [00:11<00:00, 25.6MB/s]
#  98%|#########7| 290M/298M [00:11<00:00, 25.4MB/s]
#  99%|#########8| 294M/298M [00:11<00:00, 26.4MB/s]
# 100%|#########9| 297M/298M [00:12<00:00, 26.2MB/s]
# 100%|##########| 298M/298M [00:12<00:00, 24.7MB/s]

# %% [markdown]
# ## Inference

# %%
# %cd C:/YOLO3D/
# !python inference.py \
  --weights yolov5s.pt \
  --source C:/YOLO3D/eval/image_2 \
  --reg_weights weights/resnet18.pkl \
  --model_select resnet18 \
  --output_path runs01 \
  --save_result
# Out:
# C:\YOLO3D
# C:\Users\Hripsime\anaconda3\envs\piink\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# C:\Users\Hripsime\anaconda3\envs\piink\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# inference: weights=['yolov5s.pt'], source=C:/YOLO3D/eval/image_2, data=data\coco128.yaml, imgsz=[640, 640], device=, classes=[0, 2, 3, 5], reg_weights=weights/resnet18.pkl, model_select=resnet18, calib_file=eval\camera_cal\calib_cam_to_cam.txt, show_result=False, save_result=True, output_path=runs01
# YOLOv5  2022-5-29 torch 1.12.1 CUDA:0 (NVIDIA T500, 4096MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/1 C:\YOLO3D\eval\image_2\000010.png: 224x640 13 cars, Done. (0.031s)
# Speed: 0.0ms pre-process, 30.8ms inference, 8.0ms NMS per image at shape (1, 3, 640, 640)
# YOLOv5  2022-5-29 torch 1.12.1 CUDA:0 (NVIDIA T500, 4096MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/1 C:\YOLO3D\eval\image_2\000036.png: 224x640 11 cars, Done. (0.031s)
# Speed: 0.0ms pre-process, 31.1ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# YOLOv5  2022-5-29 torch 1.12.1 CUDA:0 (NVIDIA T500, 4096MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/1 C:\YOLO3D\eval\image_2\007091.png: 224x640 8 cars, Done. (0.041s)
# Speed: 0.0ms pre-process, 41.3ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)

# %% [markdown]
# ## Show Result

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.cvtColor(cv2.imread('C:/YOLO3D/runs01/002.png'), cv2.COLOR_BGR2RGB)

plt.figure(figsize=(15, 8))
plt.imshow(img)
plt.axis('off')
plt.show()
